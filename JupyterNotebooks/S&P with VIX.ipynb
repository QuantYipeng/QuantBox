# %%
from pandas_datareader import data as web

# %%
import pandas as pd

# %%
symbols = ['^GSPC','^VIX']

# %%
data = pd.DataFrame()

# %%
for sym in symbols:
    data[sym]=web.DataReader(sym,data_source='yahoo',start='2000-01-01')['Adj Close']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4356 entries, 2000-01-03 to 2017-04-26
# Data columns (total 2 columns):
# ^GSPC    4356 non-null float64
# ^VIX     4356 non-null float64
# dtypes: float64(2)
# memory usage: 102.1 KB

# %%
from pylab import ion

# %%
ion()

# %%
import seaborn as sns; sns.set()

# %%
#Seaborn is a Python visualization library based on matplotlib. 
#It provides a high-level interface for drawing attractive statistical graphics.

# %%
data.plot()

# %%
data.tail()
# Out:
#                   ^GSPC   ^VIX
# Date
# 2017-04-20  2355.840088  14.15
# 2017-04-21  2348.689941  14.63
# 2017-04-24  2374.149902  10.84
# 2017-04-25  2388.610107  10.76
# 2017-04-26  2387.449951  10.85

# %%
import matplotlib.pyplot as plt

# %%
plt.close()

# %%
data.plot(secondary_y='^VIX')

# %%
plt.close()

# %%
import numpy as np
rets = np.log(data / data.shift(1))

# %%
rets.hist(bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB7ACACCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FB7AC24208>]], dtype=object)

# %%
sns.jointplot?

# %%
sns.jointplot(x=rets['^GSPC'],y=rets['^VIX'],kind='reg') #reg=regression
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
